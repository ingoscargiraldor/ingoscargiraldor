# %% [markdown]
# <a href="https://colab.research.google.com/github/ingoscargiraldor/ingoscargiraldor/blob/main/Separaci%C3%B3ndeDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
archivo_excel = "data/DatosCQ.xlsx"
df = pd.read_excel(archivo_excel)

# %%
df.dtypes
# Out:
# Factura                                                   int64
# Fecha de contabilización                         datetime64[ns]
# nombre_cliente                                           object
# Nombre de empleado del departamento de ventas            object
# Descripción del artículo                                 object
# Lote                                                     object
# Ciudad                                                   object
# Cantidad                                                float64
# Precio Unitario                                         float64
# Total líneas                                            float64
# Impuesto total                                          float64
# Número de referencia del SN                              object
# Código de proyecto                                      float64
# Número de artículo                                        int64
# Atributo de lote 2                                       object
# Fecha de vencimiento                             datetime64[ns]
# Fecha de fabricación                             datetime64[ns]
# DecripcionLote                                           object
# BG 1                                                      int64
# BGTR                                                      int64
# BGRS                                                      int64
# BGCS                                                      int64
# dtype: object

# %% [markdown]
# ## Cargue de datos al dataset

# %%
df.head(6)
# Out:
#    Factura Fecha de contabilización                   nombre_cliente  \
# 0    36674               2020-09-25  DUARTE RODRIGUEZ WILLIAM MOISES
# 1    36675               2020-09-25                      INVESAN SAS
# 2    36031               2020-06-12                COASPHARMA S.A.S.
# 3    36064               2020-06-18                      COLVET S.A.
# 4    36137               2020-07-01      LABORATORIOS VETERLAND LTDA
# 5    36134               2020-07-01      LABORATORIOS PHARMEK S.A.S.
#
#   Nombre de empleado del departamento de ventas  \
# 0               JONATHAN ANDRES HERNANDEZ PRADA
# 1                  JENNY MAGALY GONZALEZ FLOREZ
# 2                  JENNY MAGALY GONZALEZ FLOREZ
# 3                  JENNY MAGALY GONZALEZ FLOREZ
# 4                  JENNY MAGALY GONZALEZ FLOREZ
# 5                YENNY PATRICIA MORALES BENITEZ
#
#           Descripción del artículo          Lote         Ciudad  Cantidad  \
# 0               CIPROFLOXACINA HCL  105-200424-2         BOGOTA     150.0
# 1               CIPROFLOXACINA HCL  105-200424-2  FLORIDABLANCA     500.0
# 2  OXITETRACICLINA BASE INYECTABLE   TM191203024         BOGOTA     200.0
# 3  OXITETRACICLINA BASE INYECTABLE   TM191203024         BOGOTA     200.0
# 4  OXITETRACICLINA BASE INYECTABLE   TM191203024         BOGOTA      75.0
# 5  OXITETRACICLINA BASE INYECTABLE   TM191203024         BOGOTA      50.0
#
#    Precio Unitario  Total líneas  ...  Código de proyecto Número de artículo  \
# 0         125000.0    18750000.0  ...                 NaN         1007090000
# 1         125000.0    62500000.0  ...                 NaN         1007090000
# 2         240000.0    48000000.0  ...                 NaN         1007290000
# 3         220000.0    44000000.0  ...                 NaN         1007290000
# 4         220000.0    16500000.0  ...                 NaN         1007290000
# 5         230000.0    11500000.0  ...                 NaN         1007290000
#
#    Atributo de lote 2  Fecha de vencimiento Fecha de fabricación  \
# 0               CHINA            2024-04-23           2020-04-24
# 1               CHINA            2024-04-23           2020-04-24
# 2               CHINA            2022-12-23           2019-12-24
# 3               CHINA            2022-12-23           2019-12-24
# 4               CHINA            2022-12-23           2019-12-24
# 5               CHINA            2022-12-23           2019-12-24
#
#                                DecripcionLote BG 1 BGTR  BGRS  BGCS
# 0              CIPROFLOXACINA HCL105-200424-2    1    1     0     0
# 1              CIPROFLOXACINA HCL105-200424-2    1    1     0     0
# 2  OXITETRACICLINA BASE INYECTABLETM191203024    1    1     0     0
# 3  OXITETRACICLINA BASE INYECTABLETM191203024    1    1     0     0
# 4  OXITETRACICLINA BASE INYECTABLETM191203024    1    1     0     0
# 5  OXITETRACICLINA BASE INYECTABLETM191203024    1    1     0     0
#
# [6 rows x 22 columns]

# %%
articulos_deseados = [
    "VITAMINA C - ACIDO ASCORBICO CRISTALES",
    "NICOTIMIDA",
    "CIPERMETRINA TECNICA",
    "CAFEINA ANHIDRA",
    "ANTIPIRINA",
    "AMITRAZ TECNICO",
    "ACIDO ACETIL SALISILICO",
    "GLUCONATO DE CALCIO",
    "ALBENDAZOL MICRONIZADO",
    "CIPROFLOXACINA HCL",
    "OXITETRACICLINA HCL",
    "ETHION TECNICO (PI INDUSTRIES)"
]

# Filtra el DataFrame para incluir solo las filas con las descripciones de artículos deseadas
df = df[df["Descripción del artículo"].isin(articulos_deseados)]

# %% [markdown]
# ## Verificación de que el dataset este completo y listo para trabajar.

# %%
# Supongamos que tienes un DataFrame llamado "df" con una columna de fechas llamada "Fecha de contabilización".
# Asegúrate de que la columna de fecha esté en formato datetime.

# Definir las fechas de inicio y fin para cada conjunto
fecha_inicio_entrenamiento = "2020-02-01"
fecha_fin_entrenamiento = "2022-12-31"
fecha_inicio_validacion = "2023-01-01"
fecha_fin_validacion = "2023-06-30"
fecha_inicio_prueba = "2023-06-01"
fecha_fin_prueba = "2023-08-31"

# Filtrar los datos en los conjuntos de entrenamiento, validación y prueba
conjunto_entrenamiento = df[(df['Fecha de contabilización'] >= fecha_inicio_entrenamiento) & (df['Fecha de contabilización'] <= fecha_fin_entrenamiento)]
conjunto_validacion = df[(df['Fecha de contabilización'] >= fecha_inicio_validacion) & (df['Fecha de contabilización'] <= fecha_fin_validacion)]
conjunto_prueba = df[(df['Fecha de contabilización'] >= fecha_inicio_prueba) & (df['Fecha de contabilización'] <= fecha_fin_prueba)]

# %% [markdown]
# ## En el anterior codigo se realiza la separación de datos mediante 3 conjuntos, conjunto de entrenamiento para los dos primeros años, conjunto de validación para los primeros 6 meses del 2023 y el ultimo conjunto de prueba para los meses de Junio, Julio y Agosto de 2023.

# %%
conjunto_entrenamiento.head (6)
# Out:
#      Factura Fecha de contabilización                   nombre_cliente  \
# 0      36674               2020-09-25  DUARTE RODRIGUEZ WILLIAM MOISES
# 1      36675               2020-09-25                      INVESAN SAS
# 115    35425               2020-02-18     LABORATORIOS TIERWELT S.A.S.
# 164    36921               2020-11-05     LABORATORIOS TIERWELT S.A.S.
# 165    36708               2020-10-01      LABORATORIOS VETERLAND LTDA
# 166    37006               2020-11-13              INVERSIONES OVA SAS
#
#     Nombre de empleado del departamento de ventas Descripción del artículo  \
# 0                 JONATHAN ANDRES HERNANDEZ PRADA       CIPROFLOXACINA HCL
# 1                    JENNY MAGALY GONZALEZ FLOREZ       CIPROFLOXACINA HCL
# 115               JONATHAN ANDRES HERNANDEZ PRADA               ANTIPIRINA
# 164              VICTOR ALEJANDRO VACA CASTRILLON   ALBENDAZOL MICRONIZADO
# 165                  JENNY MAGALY GONZALEZ FLOREZ   ALBENDAZOL MICRONIZADO
# 166                YENNY PATRICIA MORALES BENITEZ   ALBENDAZOL MICRONIZADO
#
#              Lote         Ciudad  Cantidad  Precio Unitario  Total líneas  \
# 0    105-200424-2         BOGOTA     150.0         125000.0    18750000.0
# 1    105-200424-2  FLORIDABLANCA     500.0         125000.0    62500000.0
# 115    2319040216         BOGOTA      25.0          60000.0     1500000.0
# 164      20191042         BOGOTA      50.0         147500.0     7375000.0
# 165      20191042         BOGOTA     150.0         150000.0    22500000.0
# 166      20191042           COTA     100.0         150000.0    15000000.0
#
#      ...  Código de proyecto Número de artículo  Atributo de lote 2  \
# 0    ...                 NaN         1007090000               CHINA
# 1    ...                 NaN         1007090000               CHINA
# 115  ...                 NaN         1005040000               CHINA
# 164  ...                 NaN         1015010000               CHINA
# 165  ...                 NaN         1015010000               CHINA
# 166  ...                 NaN         1015010000               CHINA
#
#      Fecha de vencimiento Fecha de fabricación  \
# 0              2024-04-23           2020-04-24
# 1              2024-04-23           2020-04-24
# 115            2022-04-01           2019-05-01
# 164            2023-10-01           2019-10-01
# 165            2023-10-01           2019-10-01
# 166            2023-10-01           2019-10-01
#
#                      DecripcionLote BG 1 BGTR  BGRS  BGCS
# 0    CIPROFLOXACINA HCL105-200424-2    1    1     0     0
# 1    CIPROFLOXACINA HCL105-200424-2    1    1     0     0
# 115            ANTIPIRINA2319040216    1    0     0     0
# 164  ALBENDAZOL MICRONIZADO20191042    1    0     0     0
# 165  ALBENDAZOL MICRONIZADO20191042    1    0     0     0
# 166  ALBENDAZOL MICRONIZADO20191042    1    0     0     0
#
# [6 rows x 22 columns]

# %% [markdown]
# ## Verificación de que el dataset del conjunto de entrenamiento este completo y listo para trabajar, se divide desde enero de 2020 a Diciembre de 2022.

# %%
conjunto_validacion.head(6)
# Out:
#       Factura Fecha de contabilización              nombre_cliente  \
# 1081    41275               2023-01-18            WEISS PHARMA SAS
# 1082    41582               2023-03-17  LABORATORIOS PROVET S.A.S.
# 1083    41406               2023-02-09         INVERSIONES OVA SAS
# 1250    41401               2023-02-09         MEZCLAS BIOMIX S.A.
# 1270    41750               2023-04-21             INNOVA FEED SAS
# 1277    41499               2023-03-01   PRODUCTOS EL TOMATICO SAS
#
#      Nombre de empleado del departamento de ventas  \
# 1081                    LINA PAOLA CRISOSTOMO DIAZ
# 1082                YENNY PATRICIA MORALES BENITEZ
# 1083                YENNY PATRICIA MORALES BENITEZ
# 1250                    LINA PAOLA CRISOSTOMO DIAZ
# 1270              VICTOR ALEJANDRO VACA CASTRILLON
# 1277              VICTOR ALEJANDRO VACA CASTRILLON
#
#                     Descripción del artículo        Lote     Ciudad  Cantidad  \
# 1081                  ALBENDAZOL MICRONIZADO      211015  ZIPAQUIRA      75.0
# 1082                  ALBENDAZOL MICRONIZADO      211015      FUNZA      50.0
# 1083                  ALBENDAZOL MICRONIZADO      211015       COTA      75.0
# 1250  VITAMINA C - ACIDO ASCORBICO CRISTALES  220202-C02   SABANETA    2500.0
# 1270  VITAMINA C - ACIDO ASCORBICO CRISTALES  220202-C02      TENJO      50.0
# 1277  VITAMINA C - ACIDO ASCORBICO CRISTALES  220202-C02     BOGOTA     100.0
#
#       Precio Unitario  Total líneas  ...  Código de proyecto  \
# 1081         127000.0     9525000.0  ...                 NaN
# 1082         120000.0     6000000.0  ...                 NaN
# 1083         127000.0     9525000.0  ...                 NaN
# 1250          21000.0    52500000.0  ...                 NaN
# 1270          23500.0     1175000.0  ...                 NaN
# 1277          25000.0     2500000.0  ...                 NaN
#
#      Número de artículo  Atributo de lote 2  Fecha de vencimiento  \
# 1081         1015010000               CHINA            2024-10-23
# 1082         1015010000               CHINA            2024-10-23
# 1083         1015010000               CHINA            2024-10-23
# 1250         1033110000               CHINA            2025-02-01
# 1270         1033110000               CHINA            2025-02-01
# 1277         1033110000               CHINA            2025-02-01
#
#      Fecha de fabricación                                    DecripcionLote  \
# 1081           2021-10-24                      ALBENDAZOL MICRONIZADO211015
# 1082           2021-10-24                      ALBENDAZOL MICRONIZADO211015
# 1083           2021-10-24                      ALBENDAZOL MICRONIZADO211015
# 1250           2022-02-02  VITAMINA C - ACIDO ASCORBICO CRISTALES220202-C02
# 1270           2022-02-02  VITAMINA C - ACIDO ASCORBICO CRISTALES220202-C02
# 1277           2022-02-02  VITAMINA C - ACIDO ASCORBICO CRISTALES220202-C02
#
#      BG 1 BGTR  BGRS  BGCS
# 1081    1    1     1     0
# 1082    1    1     1     0
# 1083    1    1     1     0
# 1250    1    1     1     0
# 1270    1    1     1     0
# 1277    1    1     1     0
#
# [6 rows x 22 columns]

# %% [markdown]
# ## Verificación de que el dataset del conjunto de validación este completo y listo para trabajar, se divide desde enero de 2023 a Junio de 2023.

# %%
conjunto_prueba.head(6)
# Out:
#       Factura Fecha de contabilización               nombre_cliente  \
# 1964    42296               2023-08-10     COMPAÑIA CALIFORNIA S.A.
# 1965    42299               2023-08-10   LABORATORIOS PROVET S.A.S.
# 1966    42292               2023-08-09      VICAR FARMACEUTICA S.A.
# 2760    42046               2023-06-20  BIOSTAR PHARMACEUTICAL S.A.
# 2761    42087               2023-06-26     COMPAÑIA CALIFORNIA S.A.
# 2762    42090               2023-06-27   LABORATORIOS PROVET S.A.S.
#
#      Nombre de empleado del departamento de ventas Descripción del artículo  \
# 1964                YENNY PATRICIA MORALES BENITEZ          AMITRAZ TECNICO
# 1965                YENNY PATRICIA MORALES BENITEZ          AMITRAZ TECNICO
# 1966                  JENNY MAGALY GONZALEZ FLOREZ          AMITRAZ TECNICO
# 2760                  JENNY MAGALY GONZALEZ FLOREZ          AMITRAZ TECNICO
# 2761                YENNY PATRICIA MORALES BENITEZ          AMITRAZ TECNICO
# 2762                YENNY PATRICIA MORALES BENITEZ          AMITRAZ TECNICO
#
#           Lote     Ciudad  Cantidad  Precio Unitario  Total líneas  ...  \
# 1964  20230603     BOGOTA    1000.0         115000.0   115000000.0  ...
# 1965  20230603      FUNZA     800.0         100000.0    80000000.0  ...
# 1966  20230603     BOGOTA     150.0         110000.0    16500000.0  ...
# 2760  20230418  TOCANCIPA    1550.0         105000.0   162750000.0  ...
# 2761  20230418     BOGOTA    1000.0         115000.0   115000000.0  ...
# 2762  20230418      FUNZA    1000.0         100000.0   100000000.0  ...
#
#       Código de proyecto Número de artículo  Atributo de lote 2  \
# 1964                 NaN         1028010000               CHINA
# 1965                 NaN         1028010000               CHINA
# 1966                 NaN         1028010000               CHINA
# 2760                 NaN         1028010000               CHINA
# 2761                 NaN         1028010000               CHINA
# 2762                 NaN         1028010000               CHINA
#
#       Fecha de vencimiento Fecha de fabricación           DecripcionLote BG 1  \
# 1964            2025-06-03           2023-06-03  AMITRAZ TECNICO20230603    1
# 1965            2025-06-03           2023-06-03  AMITRAZ TECNICO20230603    1
# 1966            2025-06-03           2023-06-03  AMITRAZ TECNICO20230603    1
# 2760            2025-04-18           2023-04-18  AMITRAZ TECNICO20230418    1
# 2761            2025-04-18           2023-04-18  AMITRAZ TECNICO20230418    1
# 2762            2025-04-18           2023-04-18  AMITRAZ TECNICO20230418    1
#
#      BGTR  BGRS  BGCS
# 1964    1     1     0
# 1965    1     1     0
# 1966    1     1     0
# 2760    1     0     1
# 2761    1     0     1
# 2762    1     0     1
#
# [6 rows x 22 columns]

# %% [markdown]
# ## Verificación de que el dataset del conjunto de prueba este completo y listo para trabajar, se divide desde Junio de 2023 a Agosto de 2023.
#
# ## Ahora se tomarasn estadisticas de la variable objetivo Total lineas

# %%
conjunto_entrenamiento.shape
# Out:
# (1311, 22)

# %%
conjunto_entrenamiento["Total líneas"].nunique()
# Out:
# 395

# %%
conjunto_entrenamiento["Total líneas"].value_counts(dropna=False, normalize=False) # You can set normalize to False for calculating the absolute frecuency
# Out:
# 2750000.0     38
# 2625000.0     23
# 2500000.0     22
# 1300000.0     21
# 13000000.0    21
#               ..
# 62400000.0     1
# 7113750.0      1
# 6300000.0      1
# 24400000.0     1
# 2795000.0      1
# Name: Total líneas, Length: 395, dtype: int64
