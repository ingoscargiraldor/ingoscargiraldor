# %% [markdown]
# <a href="https://colab.research.google.com/github/ingoscargiraldor/ingoscargiraldor/blob/main/data-quality-tutorial.ipynb#scrollTo=xDdidgd_dSDV" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Quality and Cleanliness
#
# MINE-4101: Applied Data Science
# Univerisdad de los Andes
#
# **Dataset:** Homicides Colombia ([datos.gov.co](datos.gov.co))
#
# Last update: September, 2023

# %%
# !pip install pylev
# Out:
# Requirement already satisfied: pylev in /usr/local/lib/python3.10/dist-packages (1.4.0)

# %%
import re
from random import randint
from datetime import datetime
from difflib import SequenceMatcher

import numpy as np
import pandas as pd

import pylev

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## 1. Loading the data

# %%
homicides_df = pd.read_csv("./data/homicides.csv")

# %%
homicides_df.shape
# Out:
# (12400, 22)

# %%
homicides_df.dtypes
# Out:
# FECHA                 object
# DEPARTAMENTO          object
# MUNICIPIO             object
# DIA                   object
# HORA                  object
# BARRIO                object
# ZONA                  object
# CLASE DE SITIO        object
# ARMA O MEDIO          object
# MOVIL VICTIMA         object
# MOVIL AGRESOR         object
# EDAD                 float64
# GENERO                object
# ESTADO CIVIL          object
# CLASE EMPLEADO        object
# PROFESION             object
# ESCOLARIDAD           object
# PAIS NACE             object
# CODIGO DANE          float64
# AÑO DE NACIMIENTO    float64
# CÉDULA                object
# CORREO                object
# dtype: object

# %%
homicides_df.sample(5)
# Out:
#                         FECHA DEPARTAMENTO    MUNICIPIO        DIA   HORA  \
# 8465   09/09/2021 12:00:00 AM     PUTUMAYO   MOCOA (CT)  Miércoles  11:30
# 2679   03/22/2021 12:00:00 AM        VALLE    CALI (CT)    Dominog  19:50
# 732    01/20/2021 12:00:00 AM       TOLIMA  IBAGUÉ (CT)     Martes  20:05
# 2644   03/22/2021 12:00:00 AM        CAUCA      BOLÍVAR    Domingo   8:30
# 10798  11/20/2021 12:00:00 AM        VALLE    CALI (CT)    Viernes  23:50
#
#                          BARRIO    ZONA       CLASE DE SITIO   ARMA O MEDIO  \
# 8465            VDA. VILLANUEVA  URBANA  CASAS DE HABITACION  ARMA DE FUEGO
# 2679       VILLA SAN MARCOS E14  URBANA        VIAS PUBLICAS  ARMA DE FUEGO
# 732    INDEPENDIENTE PARTE BAJA  URBANA        VIAS PUBLICAS  ARMA DE FUEGO
# 2644            VDA LA ESTRELLA   RURAL                 RIOS  ARMA DE FUEGO
# 10798              SINDICAL E12  URBANA        VIAS PUBLICAS  ARMA DE FUEGO
#
#       MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 8465          A PIE         A PIE  43.0  MASCULINO     SEPARADO
# 2679          A PIE         A PIE  21.0  MASCULINO      SOLTERO
# 732           A PIE         A PIE  23.0   FEMENINO      SOLTERO
# 2644          A PIE         A PIE  28.0   FEMENINO  UNION LIBRE
# 10798         A PIE         A PIE  58.0  MASCULINO      SOLTERO
#
#             CLASE EMPLEADO     PROFESION ESCOLARIDAD PAIS NACE  CODIGO DANE  \
# 8465         INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA   86001000.0
# 2679   EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA   76001000.0
# 732             ESTUDIANTE  NO REPORTADO  SECUNDARIA  COLOMBIA   73001000.0
# 2644         INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA   19100000.0
# 10798  EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA  COLOMBIA   76001000.0
#
#        AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 8465              1972.0  43-207  iegpmf8944@unidatos.edu.co
# 2679              1994.0  40-751   correo333@unidatos.edu.co
# 732               1992.0  52-640  cbghch2138@unidatos.edu.co
# 2644              1987.0  18-639  hhgbmc4233@unidatos.edu.co
# 10798             1957.0  45-384  sdurua5609@unidatos.edu.co

# %% [markdown]
# ## 2. Working with datetimes

# %%
# Creating a lambda expression for datetime parsing
dateparse = lambda x: datetime.strptime(x, "%m/%d/%Y %H:%M:%S %p")

# %%
# Applying the validation to all values in the column
homicides_df["FECHA"].apply(dateparse)

# IT IS EXPECTED TO HAVE AN ERROR BECAUSE SOME VALUES DOESN'T FIT THE FORMAT
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-270-783dfaf536c2> in <cell line: 2>()
#       1 # Applying the validation to all values in the column
# ----> 2 homicides_df["FECHA"].apply(dateparse)
#       3
#       4 # IT IS EXPECTED TO HAVE AN ERROR BECAUSE SOME VALUES DOESN'T FIT THE FORMAT
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
#    1173                 values = obj.astype(object)._values
# -> 1174                 mapped = lib.map_infer(
#    1175                     values,
#    1176                     f,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-269-4c2bbe61e019> in <lambda>(x)
#       1 # Creating a lambda expression for datetime parsing
# ----> 2 dateparse = lambda x: datetime.strptime(x, "%m/%d/%Y %H:%M:%S %p")
#
# /usr/lib/python3.10/_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# /usr/lib/python3.10/_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
#
# ValueError: time data '13/12/2021 12:00:00 AM' does not match format '%m/%d/%Y %H:%M:%S %p'

# %%
# Creating a function for validating which value is causing the previous error
def error_in_format(x):
    try:
        datetime.strptime(x, "%m/%d/%Y %H:%M:%S %p")
        return False
    except:
        return True

# %%
# Using the function for validation
homicides_df.loc[homicides_df["FECHA"].apply(error_in_format)]
# Out:
#                         FECHA DEPARTAMENTO       MUNICIPIO      DIA   HORA  \
# 486    13/12/2021 12:00:00 AM        VALLE       CALI (CT)    kunes  23:00
# 695    30/01/2021 12:00:00 AM      BOLÍVAR  CARTAGENA (CT)    Lunes   5:30
# 1250   18/05/2021 12:00:00 AM        HUILA         TESALIA   Jueves  19:30
# 12168  12/25/2021 12:00:00 MM        VALLE         PALMIRA  Viernes  15:30
# 12399                   TOTAL          NaN             NaN      NaN    NaN
#
#                 BARRIO    ZONA       CLASE DE SITIO   ARMA O MEDIO  \
# 486         MOJICA E15  URBANA        VIAS PUBLICAS  ARMA DE FUEGO
# 695    REP. DEL LIBANO  URBANA        VIAS PUBLICAS    ARMA BLANCA
# 1250    VEREDA PACARNI   RURAL  CASAS DE HABITACION  ARMA DE FUEGO
# 12168        LA EMILIA  URBANA        VIAS PUBLICAS  ARMA DE FUEGO
# 12399              NaN     NaN                  NaN            NaN
#
#       MOVIL VICTIMA          MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 486           A PIE                  A PIE  26.0  MASCULINO      SOLTERO
# 695    NO REPORTADO                  A PIE  25.0  MASCULINO      SOLTERO
# 1250          A PIE                  A PIE  34.0   FEMENINO      SOLTERO
# 12168         A PIE  CONDUCTOR MOTOCICLETA  17.0  MASCULINO      SOLTERO
# 12399           NaN                    NaN   NaN        NaN          NaN
#
#             CLASE EMPLEADO     PROFESION ESCOLARIDAD PAIS NACE  CODIGO DANE  \
# 486          INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA   76001000.0
# 695    EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA   13001000.0
# 1250            AGRICULTOR  NO REPORTADO    PRIMARIA  COLOMBIA   41797000.0
# 12168  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA   76520000.0
# 12399                  NaN           NaN         NaN       NaN          NaN
#
#        AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 486                 89.0  80-330        lujhdf9132@gmail.com
# 695               1990.0  12-915  ghumtg4094@unidatos.edu.co
# 1250              1981.0  99-095        sdaggf6639@gmail.com
# 12168             1998.0  16-362        uschca1775@gmail.com
# 12399                NaN     NaN                         NaN

# %%
# Deleting a row by its index
homicides_df.drop([486, 695, 1250, 12168, 12399], inplace=True)

# %%
# Trying to parse the datetime string again
homicides_df["FECHA"] = homicides_df["FECHA"].apply(dateparse)

# %%
homicides_df.dtypes
# Out:
# FECHA                datetime64[ns]
# DEPARTAMENTO                 object
# MUNICIPIO                    object
# DIA                          object
# HORA                         object
# BARRIO                       object
# ZONA                         object
# CLASE DE SITIO               object
# ARMA O MEDIO                 object
# MOVIL VICTIMA                object
# MOVIL AGRESOR                object
# EDAD                        float64
# GENERO                       object
# ESTADO CIVIL                 object
# CLASE EMPLEADO               object
# PROFESION                    object
# ESCOLARIDAD                  object
# PAIS NACE                    object
# CODIGO DANE                 float64
# AÑO DE NACIMIENTO           float64
# CÉDULA                       object
# CORREO                       object
# dtype: object

# %%
# Counting homicides by hour
homicides_df["FECHA"].dt.hour.value_counts()

# All datetime hour parts are the same
# Out:
# 12    12395
# Name: FECHA, dtype: int64

# %% [markdown]
# *The homicide hour is available in a different column!*

# %%
# Merging both columns
homicides_df["FECHA"] = homicides_df["FECHA"].astype(str).apply(lambda x: x[:11])+homicides_df["HORA"]

# %%
# Deleting redundant column
homicides_df.drop(columns=["HORA"], inplace=True)

# %%
# Making a new expression for datetime parsing
dateparse = lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M")

# %%
# Applying the expression
homicides_df["FECHA"] = homicides_df["FECHA"].apply(dateparse)

# %%
homicides_df.dtypes
# Out:
# FECHA                datetime64[ns]
# DEPARTAMENTO                 object
# MUNICIPIO                    object
# DIA                          object
# BARRIO                       object
# ZONA                         object
# CLASE DE SITIO               object
# ARMA O MEDIO                 object
# MOVIL VICTIMA                object
# MOVIL AGRESOR                object
# EDAD                        float64
# GENERO                       object
# ESTADO CIVIL                 object
# CLASE EMPLEADO               object
# PROFESION                    object
# ESCOLARIDAD                  object
# PAIS NACE                    object
# CODIGO DANE                 float64
# AÑO DE NACIMIENTO           float64
# CÉDULA                       object
# CORREO                       object
# dtype: object

# %%
homicides_df.sample(5)
# Out:
#                    FECHA  DEPARTAMENTO            MUNICIPIO      DIA  \
# 3316 2021-04-11 01:30:00        NARIÑO             LA UNIÓN   Sábado
# 2680 2021-03-22 21:50:00         VALLE  GUADALAJARA DE BUGA  Domingo
# 5045 2021-06-01 00:05:00     ANTIOQUIA        MEDELLÍN (CT)    Lunes
# 8191 2021-08-31 22:10:00         VALLE            CALI (CT)    Lunes
# 1766 2021-02-23 08:00:00  CUNDINAMARCA     BOGOTÁ D.C. (CT)    Lunes
#
#                                   BARRIO    ZONA CLASE DE SITIO  \
# 3316                       VDA LA MERCED   RURAL  VIAS PUBLICAS
# 2680  VIA BUGA NO REPORTADO LA MAGDALENA   RURAL  VIAS PUBLICAS
# 5045       LA CANDELARIA CNO REPORTADO10  URBANA  VIAS PUBLICAS
# 8191                       EL RETIRO E15  URBANA  VIAS PUBLICAS
# 1766         LLANO GRANDE ENO REPORTADO8  URBANA  VIAS PUBLICAS
#
#        ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 3316  ARMA DE FUEGO         A PIE         A PIE  56.0   FEMENINO      SOLTERO
# 2680  ARMA DE FUEGO         A PIE         A PIE  35.0  MASCULINO  UNION LIBRE
# 5045    ARMA BLANCA         A PIE         A PIE  31.0  MASCULINO      SOLTERO
# 8191  ARMA DE FUEGO         A PIE         A PIE  32.0  MASCULINO      SOLTERO
# 1766  ARMA DE FUEGO         A PIE         A PIE  34.0  MASCULINO      SOLTERO
#
#            CLASE EMPLEADO     PROFESION ESCOLARIDAD PAIS NACE  CODIGO DANE  \
# 3316        INDEPENDIENTE  NO REPORTADO    PRIMARIA  COLOMBIA   52399000.0
# 2680  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA   76111000.0
# 5045          DESEMPLEADO  NO REPORTADO  SECUNDARIA  COLOMBIA    5001000.0
# 8191        INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA   76001000.0
# 1766          DESEMPLEADO  NO REPORTADO  SECUNDARIA  COLOMBIA   11001000.0
#
#       AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 3316             1959.0  31-414        knjtpm9667@gmail.com
# 2680             1980.0  55-562   correo592@unidatos.edu.co
# 5045             1984.0  60-739  ggplmh7499@unidatos.edu.co
# 8191             1983.0  31-012  dfbbek5904@unidatos.edu.co
# 1766             1981.0  42-944  brmhua9235@unidatos.edu.co

# %% [markdown]
# ## 2. Fixing categorical column

# %%
# Creating a dictionary representing the valid departments for Colombia
departments_list = ['ANTIOQUIA', 'ATLÁNTICO', 'BOLÍVAR', 'BOYACÁ', 'CALDAS', 'CAQUETÁ',
       'CASANARE', 'CAUCA', 'CESAR', 'CHOCÓ', 'CÓRDOBA', 'META',
       'CUNDINAMARCA', 'HUILA', 'MAGDALENA', 'NARIÑO', 'PUTUMAYO',
       'RISARALDA', 'SANTANDER', 'SUCRE', 'TOLIMA', 'VALLE',
       'NORTE DE SANTANDER', 'GUAJIRA', 'QUINDÍO', 'SAN ANDRÉS Y PROVIDENCIA', 'ARAUCA',
       'GUAINÍA', 'VICHADA', 'VAUPÉS', 'GUAVIARE', 'AMAZONAS']

# %%
# Finding values not matching with the dictionary
homicides_df.loc[~homicides_df["DEPARTAMENTO"].isin(departments_list), "DEPARTAMENTO"].unique()
# Out:
# array(['SAN ANDRÉS', 'N. DE SANTANDER'], dtype=object)

# %% [markdown]
# <span style="color:red">TODO: Replace the values identified as error to a valid value from the dictionary.</span>
#
# <span style="color:red">Hint: You can use the replace() pandas function.</span>

# %%
homicides_df = homicides_df.replace('SAN ANDRÉS', 'SAN ANDRÉS Y PROVIDENCIA')

# %%
homicides_df = homicides_df.replace('N. DE SANTANDER', 'NORTE DE SANTANDER')

# %%
# Finding values not matching with the dictionary
homicides_df.loc[~homicides_df["DEPARTAMENTO"].isin(departments_list), "DEPARTAMENTO"].unique()
# Out:
# array([], dtype=object)

# %% [markdown]
# ## 3. Analyzing potential duplicates

# %%
# Detecting duplicates by "CÉDULA" column
duplicates_by_cedula = homicides_df.loc[homicides_df["CÉDULA"].duplicated(keep=False)]

# %%
duplicates_by_cedula.shape
# Out:
# (1627, 21)

# %%
duplicates_by_cedula.sort_values("CÉDULA", ascending=True).head(6)
# Out:
#                     FECHA DEPARTAMENTO      MUNICIPIO      DIA  \
# 4041  2021-05-03 23:30:00        CAUCA       EL TAMBO  Domingo
# 3810  2021-04-26 03:00:00    ANTIOQUIA   SAN JERÓNIMO  Domingo
# 693   2021-01-19 05:30:00    ANTIOQUIA         SALGAR    Lunes
# 10796 2021-11-20 03:00:00        VALLE      CALI (CT)  Viernes
# 2386  2021-03-14 02:00:00         META  FUENTE DE ORO   Sábado
# 138   2021-01-02 06:20:00        CAUCA         SOTARA  Viernes
#
#                     BARRIO    ZONA                      CLASE DE SITIO  \
# 4041           LA VICTORIA   RURAL         BARES, CANTINAS Y SIMILARES
# 3810              LA PLAYA  URBANA  HOTELES, RESIDENCIAS, Y SIMILARES.
# 693              LA HABANA  URBANA                       VIAS PUBLICAS
# 10796   POTRERO GRANDE E21  URBANA                       VIAS PUBLICAS
# 2386   VEREDA PUERTO NUEVO   RURAL         BARES, CANTINAS Y SIMILARES
# 138                 CENTRO   RURAL                       VIAS PUBLICAS
#
#              ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO  \
# 4041        ARMA DE FUEGO         A PIE         A PIE  45.0  MASCULINO
# 3810   CUERDA/SOGA/CADENA         A PIE         A PIE  25.0  MASCULINO
# 693         ARMA DE FUEGO         A PIE         A PIE  58.0  MASCULINO
# 10796       ARMA DE FUEGO         A PIE         A PIE  21.0  MASCULINO
# 2386          ARMA BLANCA         A PIE         A PIE  42.0  MASCULINO
# 138           ARMA BLANCA         A PIE         A PIE  22.0  MASCULINO
#
#       ESTADO CIVIL       CLASE EMPLEADO     PROFESION ESCOLARIDAD PAIS NACE  \
# 4041   UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA  COLOMBIA
# 3810       SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA
# 693        SOLTERO           AGRICULTOR  NO REPORTADO    PRIMARIA  COLOMBIA
# 10796      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA
# 2386       SOLTERO        INDEPENDIENTE  NO REPORTADO    PRIMARIA  COLOMBIA
# 138        SOLTERO    EMPLEADO EJERCITO  NO REPORTADO  SECUNDARIA  COLOMBIA
#
#        CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 4041    19256000.0             1970.0  10-048        aitufn1227@gmail.com
# 3810     5656000.0             1990.0  10-048  ibbcpu2509@unidatos.edu.co
# 693      5642000.0               57.0  10-079  unhoqj1172@unidatos.edu.co
# 10796   76001000.0             1994.0  10-079  iknnoj8430@unidatos.edu.co
# 2386    50287000.0             1973.0  10-255  afompq7113@unidatos.edu.co
# 138     19760000.0             1993.0  10-255  cobgqs8819@unidatos.edu.co

# %% [markdown]
# <span style="color:red">TODO: Delete records with "CÉDULA" duplicated.</span>
#
# <span style="color:red">Hint: You can use drop_duplicates() pandas function.</span>

# %%
clear_df = homicides_df.drop_duplicates(subset=['CÉDULA'])
# Detecting duplicates by "CÉDULA" column
duplicates_by_cedula_2 = clear_df.loc[clear_df["CÉDULA"].duplicated(keep=False)]
duplicates_by_cedula_2.sort_values("CÉDULA", ascending=True).head(6)
# Out:
# Empty DataFrame
# Columns: [FECHA, DEPARTAMENTO, MUNICIPIO, DIA, BARRIO, ZONA, CLASE DE SITIO, ARMA O MEDIO, MOVIL VICTIMA, MOVIL AGRESOR, EDAD, GENERO, ESTADO CIVIL, CLASE EMPLEADO, PROFESION, ESCOLARIDAD, PAIS NACE, CODIGO DANE, AÑO DE NACIMIENTO, CÉDULA, CORREO]
# Index: []

# %% [markdown]
# ## 4. Fixing formats

# %%
# Using regular expressions for validating if "CÉDULA" values match the pattern XX-XXX
cedula_malformed = homicides_df.loc[homicides_df["CÉDULA"].apply(lambda x: (re.match("\d{2}-\d{3}", x) is None))]

# %%
cedula_malformed.shape
# Out:
# (28, 21)

# %%
cedula_malformed.head(6)
# Out:
#                    FECHA DEPARTAMENTO          MUNICIPIO      DIA  \
# 172  2021-01-03 11:00:00         META            MESETAS   Sábado
# 1114 2021-02-01 12:30:00    ATLÁNTICO  BARRANQUILLA (CT)  Domingo
# 2119 2021-03-06 15:30:00        VALLE          CALI (CT)  Viernes
# 3309 2021-04-11 10:30:00      CAQUETÁ     FLORENCIA (CT)   Sávado
# 3409 2021-04-13 23:20:00      CÓRDOBA            SAHAGÚN    Lunes
# 3588 2021-04-19 20:00:00      BOLÍVAR     CARTAGENA (CT)  Domingo
#
#                             BARRIO    ZONA         CLASE DE SITIO  \
# 172                VEREDA EL CAFRE   RURAL         ZONA SELVÁTICA
# 1114                        LA LUZ  URBANA          VIAS PUBLICAS
# 2119           QUINTAS DEL SOL E14  URBANA  DENTRO DE LA VIVIENDA
# 3309                   VIA MORELIA   RURAL               CARCELES
# 3409  CORREGIMIENTO DE BAJO GRANDE  URBANA               BILLARES
# 3588                  LA ESPERANZA  URBANA          VIAS PUBLICAS
#
#           ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO  \
# 172   MINA ANTIPERSONA         A PIE         A PIE  24.0  MASCULINO
# 1114     ARMA DE FUEGO         A PIE         A PIE  29.0  MASCULINO
# 2119       ARMA BLANCA         A PIE         A PIE  20.0   FEMENINO
# 3309         CORTANTES         A PIE         A PIE  23.0  MASCULINO
# 3409      CONTUNDENTES         A PIE         A PIE  49.0  MASCULINO
# 3588     ARMA DE FUEGO         A PIE         A PIE  45.0  MASCULINO
#
#      ESTADO CIVIL       CLASE EMPLEADO     PROFESION   ESCOLARIDAD  \
# 172       SOLTERO    EMPLEADO EJERCITO  NO REPORTADO    SECUNDARIA
# 1114      SOLTERO        INDEPENDIENTE  NO REPORTADO      PRIMARIA
# 2119  UNION LIBRE  EMPLEADO PARTICULAR  NO REPORTADO    SECUNDARIA
# 3309      SOLTERO        INDEPENDIENTE  NO REPORTADO      PRIMARIA
# 3409      SOLTERO        INDEPENDIENTE  NO REPORTADO    SECUNDARIA
# 3588      SOLTERO          DESEMPLEADO  NO REPORTADO  NO REPORTADO
#
#          PAIS NACE  CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA  \
# 172       COLOMBIA   50330000.0             1991.0  680-21
# 1114      COLOMBIA    8001000.0             1986.0  140-17
# 2119      COLOMBIA   76001000.0             1995.0  975-31
# 3309      COLOMBIA   18001000.0             1992.0  348-66
# 3409      COLOMBIA   23660000.0             1966.0  496-18
# 3588  NO REPORTADO   13001000.0             1970.0  188-03
#
#                           CORREO
# 172         oohghd8899@gmail.com
# 1114  correo5853@colombia.gov.co
# 2119  ohbqrk3631@unidatos.edu.co
# 3309  pdkqur8407@unidatos.edu.co
# 3409  fdbbeo6751@unidatos.edu.co
# 3588  diebuo5651@unidatos.edu.co

# %% [markdown]
# <span style="color:red">TODO: Fix the malformed "CÉDULA" values.</span>

# %%
len(cedula_malformed)
# Out:
# 28

# %%
cedula_malformed_2 = homicides_df
cedula_malformed_2["CÉDULA"] = homicides_df["CÉDULA"].str.replace('-', '')
cedula_malformed_2["CÉDULA"] = cedula_malformed_2["CÉDULA"].str.replace(r'^(\d{2})(\d{3})$', r'\1-\2')
cedula_malformed_2.head(6)
# Out:
# <ipython-input-296-a8868aa26215>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   cedula_malformed_2["CÉDULA"] = cedula_malformed_2["CÉDULA"].str.replace(r'^(\d{2})(\d{3})$', r'\1-\2')
#                 FECHA DEPARTAMENTO      MUNICIPIO     DIA  \
# 0 2021-01-01 06:00:00    ANTIOQUIA          AMAGÁ  Jueves
# 1 2021-01-01 09:00:00    ANTIOQUIA        BARBOSA  Jueves
# 2 2021-01-01 19:00:00    ANTIOQUIA       EL BAGRE  Jueves
# 3 2021-01-01 11:20:00    ANTIOQUIA         JARDÍN  Jueves
# 4 2021-01-01 15:00:00    ANTIOQUIA  MEDELLÍN (CT)   Juees
# 5 2021-01-01 00:47:00    ANTIOQUIA  MEDELLÍN (CT)   Juees
#
#                      BARRIO    ZONA                      CLASE DE SITIO  \
# 0                 EL VOLCAN   RURAL                              TIENDA
# 1            VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2             PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4  PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# 5    CORDOBA CNO REPORTADO7  URBANA                       VIAS PUBLICAS
#
#     ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 0    ARMA BLANCA         A PIE         A PIE  44.0  MASCULINO       CASADO
# 1    ARMA BLANCA         A PIE         A PIE  30.0  MASCULINO      SOLTERO
# 2    ARMA BLANCA         A PIE         A PIE  33.0  MASCULINO  UNION LIBRE
# 3    ARMA BLANCA         A PIE         A PIE  40.0  MASCULINO       CASADO
# 4   CONTUNDENTES         A PIE         A PIE  66.0  MASCULINO  UNION LIBRE
# 5  ARMA DE FUEGO         A PIE         A PIE  42.0  MASCULINO      SOLTERO
#
#   CLASE EMPLEADO     PROFESION ESCOLARIDAD     PAIS NACE  CODIGO DANE  \
# 0  INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA    5030000.0
# 1    DESEMPLEADO  NO REPORTADO  SECUNDARIA  NO REPORTADO    5079000.0
# 2     AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5250000.0
# 3     AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5364000.0
# 4    DESEMPLEADO  NO REPORTADO    PRIMARIA      COLOMBIA    5001000.0
# 5  INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA    5001000.0
#
#    AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 0             1971.0  42-908  agbnqg2122@unidatos.edu.co
# 1             1985.0  15-183        rbkeui3584@gmail.com
# 2             1982.0  84-786  aorkhf9155@unidatos.edu.co
# 3             1975.0  31-289  dhtemr6623@unidatos.edu.co
# 4             1949.0  66-363  artatj9268@unidatos.edu.co
# 5             1973.0  54-450  grlcsj8696@unidatos.edu.co

# %%
cedula_malformed = cedula_malformed_2.loc[cedula_malformed_2["CÉDULA"].apply(lambda x: (re.match("\d{2}-\d{3}", x) is None))]
len(cedula_malformed)
# Out:
# 0

# %%
len(homicides_df)
# Out:
# 12395

# %%
len(cedula_malformed_2)
# Out:
# 12395

# %%
cedula_malformed_2.iloc[172]
# Out:
# FECHA                 2021-01-03 11:00:00
# DEPARTAMENTO                         META
# MUNICIPIO                         MESETAS
# DIA                                Sábado
# BARRIO                    VEREDA EL CAFRE
# ZONA                                RURAL
# CLASE DE SITIO             ZONA SELVÁTICA
# ARMA O MEDIO             MINA ANTIPERSONA
# MOVIL VICTIMA                       A PIE
# MOVIL AGRESOR                       A PIE
# EDAD                                 24.0
# GENERO                          MASCULINO
# ESTADO CIVIL                      SOLTERO
# CLASE EMPLEADO          EMPLEADO EJERCITO
# PROFESION                    NO REPORTADO
# ESCOLARIDAD                    SECUNDARIA
# PAIS NACE                        COLOMBIA
# CODIGO DANE                    50330000.0
# AÑO DE NACIMIENTO                  1991.0
# CÉDULA                             68-021
# CORREO               oohghd8899@gmail.com
# Name: 172, dtype: object

# %% [markdown]
# <span style="color:red">TODO: Make something similar to check and fix the "CORREO" column (PATTERN: 4 digits before the @, only .edu.co and .com domains are allowed)</span>

# %%
mail_malformed = homicides_df.loc[homicides_df["CORREO"].apply(lambda x: (re.match("\w*[0-9]{4,}@*.*", x) is None))]
mail_malformed.shape
# Out:
# (1282, 21)

# %%
# Using regular expressions for validating if "CÉDULA" values match the pattern XX-XXX
mail_malformed = homicides_df.loc[homicides_df["CORREO"].apply(lambda x: (re.match("^\w{4,}@[A-Za-z0-9.-]+\.(edu\.co|com)$", x) is None))]
mail_malformed.shape
# Out:
# (1011, 21)

# %%
mail_malformed.head(10)
# Out:
#                   FECHA  DEPARTAMENTO             MUNICIPIO      DIA  \
# 36  2021-01-01 08:00:00         CAUCA                 PATÍA   Jueves
# 47  2021-01-01 09:00:00         CHOCÓ                  TADÓ   Jueves
# 55  2021-01-01 01:30:00  CUNDINAMARCA      BOGOTÁ D.C. (CT)   Jueves
# 84  2021-01-01 08:40:00        NARIÑO  SAN ANDRES DE TUMACO   Jueces
# 104 2021-01-01 03:40:00         VALLE             CALI (CT)   Jueces
# 110 2021-01-01 09:03:00         VALLE             CALI (CT)   Jueves
# 122 2021-01-01 12:00:00         VALLE               PALMIRA    Juees
# 131 2021-01-02 22:20:00        CALDAS        MANIZALES (CT)  Viernes
# 148 2021-01-02 10:30:00         VALLE             CALI (CT)   iernes
# 150 2021-01-02 18:25:00         VALLE               PALMIRA  Viernes
#
#                         BARRIO    ZONA CLASE DE SITIO   ARMA O MEDIO  \
# 36      C/MIENTO PIEDRASENTADA   RURAL      CARRETERA  ARMA DE FUEGO
# 47                     POPULAR  URBANA  VIAS PUBLICAS  ARMA DE FUEGO
# 55   ÁLVARO BERNAL SEGURA E-19  URBANA  VIAS PUBLICAS  ARMA DE FUEGO
# 84                      PANAMA  URBANA  VIAS PUBLICAS  ARMA DE FUEGO
# 104          12 DE OCTUBRE E12  URBANA  VIAS PUBLICAS    ARMA BLANCA
# 110              EL RETIRO E15  URBANA  VIAS PUBLICAS  ARMA DE FUEGO
# 122                     LORETO  URBANA  VIAS PUBLICAS    ARMA BLANCA
# 131              SAN SEBASTIAN  URBANA  VIAS PUBLICAS  ARMA DE FUEGO
# 148        QUINTAS DEL SOL E14  URBANA  VIAS PUBLICAS  ARMA DE FUEGO
# 150                LA TRINIDAD  URBANA   RESTAURANTES  ARMA DE FUEGO
#
#     MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 36       VEHICULO         A PIE  26.0  MASCULINO      SOLTERO
# 47          A PIE         A PIE  34.0  MASCULINO       CASADO
# 55          A PIE         A PIE  25.0  MASCULINO  UNION LIBRE
# 84          A PIE         A PIE  26.0  MASCULINO      SOLTERO
# 104         A PIE         A PIE  49.0  MASCULINO       CASADO
# 110         A PIE         A PIE  25.0  MASCULINO      SOLTERO
# 122         A PIE         A PIE  24.0  MASCULINO      SOLTERO
# 131         A PIE         A PIE  18.0  MASCULINO      SOLTERO
# 148         A PIE         A PIE  25.0  MASCULINO      SOLTERO
# 150         A PIE         A PIE  18.0  MASCULINO      SOLTERO
#
#           CLASE EMPLEADO     PROFESION ESCOLARIDAD PAIS NACE  CODIGO DANE  \
# 36     EMPLEADO EJERCITO  NO REPORTADO  SECUNDARIA  COLOMBIA   19532000.0
# 47     EMPLEADO POLICIAL       POLICIA     TECNICO  COLOMBIA   27787000.0
# 55           DESEMPLEADO  NO REPORTADO  SECUNDARIA  COLOMBIA   11001000.0
# 84         INDEPENDIENTE  NO REPORTADO    PRIMARIA  COLOMBIA   52835000.0
# 104     EMPLEADO PUBLICO  NO REPORTADO  SECUNDARIA  COLOMBIA   76001000.0
# 110  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA   76001000.0
# 122          DESEMPLEADO  NO REPORTADO    PRIMARIA  COLOMBIA   76520000.0
# 131  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA   17001000.0
# 148        INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA   76001000.0
# 150          DESEMPLEADO  NO REPORTADO    PRIMARIA  COLOMBIA   76520000.0
#
#      AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 36              1989.0  69-084  correo4714@colombia.gov.co
# 47              1981.0  29-957  correo8297@colombia.gov.co
# 55              1990.0  35-260  correo7285@colombia.gov.co
# 84              1989.0  55-611  correo8342@colombia.gov.co
# 104               66.0  87-287  correo6479@colombia.gov.co
# 110             1990.0  52-177  correo1928@colombia.gov.co
# 122             1991.0  81-854  correo5547@colombia.gov.co
# 131             1997.0  90-886  correo7410@colombia.gov.co
# 148             1990.0  63-712  correo3176@colombia.gov.co
# 150             1997.0  39-731  correo1372@colombia.gov.co

# %% [markdown]
# ## 5. Automating imputation of categorical values

# %%
homicides_df["DIA"].unique()
# Out:
# array(['Jueves', 'Juees', 'Jueces', 'juves', 'Juevrs', 'Viernes',
#        'Viermes', 'iernes', 'virnes', 'Vierens', 'Sábado', 'Sabadi',
#        'Sabado', 'sábad', 'Sávado', 'Ssbado', 'Domingo', 'Domungo',
#        'Doningo', 'domungo', 'Lunes', 'lune', 'Luns', 'Lumes', 'kunes',
#        'Lnues', 'Martes', 'Mates', 'Marte', 'mates', 'Miércoles',
#        'Miwrcoles', 'Mircoles', 'Voernes', 'domnigo', 'Maryes',
#        'Miercoles', 'miércles', 'Dominog', 'Msrtes', 'Mirrcoles'],
#       dtype=object)

# %%
homicides_df["DIA"].value_counts()
# Out:
# Domingo      2069
# Sábado       1400
# Lunes        1295
# Jueves       1248
# Viernes      1184
# Martes       1113
# Miércoles    1053
# Juees         162
# Domungo       151
# domnigo       146
# domungo       137
# Dominog       133
# Doningo       129
# Sávado        102
# Sabado        100
# Viermes        99
# Voernes        96
# lune           89
# virnes         87
# Vierens        85
# iernes         84
# sábad          84
# Mates          83
# Jueces         83
# Ssbado         82
# juves          82
# Lnues          81
# Luns           80
# Sabadi         80
# Miwrcoles      78
# kunes          70
# miércles       69
# Msrtes         66
# Mircoles       65
# Maryes         65
# mates          64
# Lumes          64
# Juevrs         62
# Marte          62
# Miercoles      58
# Mirrcoles      55
# Name: DIA, dtype: int64

# %%
# Calculating the distance between two words using the Levenshtein distance
pylev.levenshtein("sábado", "sabaod")
# Out:
# 3

# %%
pylev.levenshtein("sábado", "viernes")
# Out:
# 7

# %%
SequenceMatcher(None, "sábado", "sabaod").ratio()
# Out:
# 0.6666666666666666

# %%
SequenceMatcher(None, "sábado", "viernes").ratio()
# Out:
# 0.15384615384615385

# %% [markdown]
# <span style="color:red">How does SequenceMatcher works? How this differ from the Levenshtein distance?</span>

# %% [markdown]
#  SequenceMatcher implementa un método heurístico que identifica automáticamente a ciertos elementos como no deseados. El método heurístico consiste en contar cuantas veces aparece cada elemento en la secuencia. Si las apariciones del duplicado de un elemento (después del primero) contabilizan mas del 1% de la secuencia
#
#  SequenceMatcher se utiliza cuando se requiere una medida mas precisa y Levenshtein cuando se requiere de una medida rapida

# %% [markdown]
# <span style="color:red">TODO: Create a function to fix the digitation errors for the "DIA" column.</span>

# %%
days_list = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes", "Sábado", "Domingo"]

# %%
days_list = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes", "Sábado", "Domingo"]
days_aut = homicides_df
def encontrar_dia_similar(valor):
  mejor_coincidencia = None
  mejor_distancia = float('inf')
  for dia in days_list:
      distancia = pylev.levenshtein(valor.lower(), dia.lower())
      if distancia < mejor_distancia:
          mejor_coincidencia = dia
          mejor_distancia = distancia
  return mejor_coincidencia
days_aut['DIA'] = days_aut['DIA'].apply(encontrar_dia_similar)
days_aut["DIA"].unique()
# Out:
# array(['Jueves', 'Viernes', 'Sábado', 'Domingo', 'Lunes', 'Martes',
#        'Miércoles'], dtype=object)

# %%
days_aut.head(100)
# Out:
#                  FECHA DEPARTAMENTO      MUNICIPIO     DIA  \
# 0  2021-01-01 06:00:00    ANTIOQUIA          AMAGÁ  Jueves
# 1  2021-01-01 09:00:00    ANTIOQUIA        BARBOSA  Jueves
# 2  2021-01-01 19:00:00    ANTIOQUIA       EL BAGRE  Jueves
# 3  2021-01-01 11:20:00    ANTIOQUIA         JARDÍN  Jueves
# 4  2021-01-01 15:00:00    ANTIOQUIA  MEDELLÍN (CT)  Jueves
# ..                 ...          ...            ...     ...
# 95 2021-01-01 04:34:00       TOLIMA          GUAMO  Jueves
# 96 2021-01-01 00:00:00       TOLIMA    IBAGUÉ (CT)  Jueves
# 97 2021-01-01 03:01:00       TOLIMA      MARIQUITA  Jueves
# 98 2021-01-01 09:00:00       TOLIMA         ORTEGA  Jueves
# 99 2021-01-01 04:50:00       TOLIMA        SALDAÑA  Jueves
#
#                       BARRIO    ZONA                      CLASE DE SITIO  \
# 0                  EL VOLCAN   RURAL                              TIENDA
# 1             VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2              PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                 CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4   PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# ..                       ...     ...                                 ...
# 95     INVASION LA CARRILERA  URBANA                       VIAS PUBLICAS
# 96                 COMUNEROS  URBANA                       VIAS PUBLICAS
# 97                 EL DORADO  URBANA                       VIAS PUBLICAS
# 98        VRDA. LOS GUAYABOS   RURAL                  FINCAS Y SIMILARES
# 99                    CENTRO  URBANA                       VIAS PUBLICAS
#
#      ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 0     ARMA BLANCA         A PIE         A PIE  44.0  MASCULINO       CASADO
# 1     ARMA BLANCA         A PIE         A PIE  30.0  MASCULINO      SOLTERO
# 2     ARMA BLANCA         A PIE         A PIE  33.0  MASCULINO  UNION LIBRE
# 3     ARMA BLANCA         A PIE         A PIE  40.0  MASCULINO       CASADO
# 4    CONTUNDENTES         A PIE         A PIE  66.0  MASCULINO  UNION LIBRE
# ..            ...           ...           ...   ...        ...          ...
# 95    ARMA BLANCA         A PIE         A PIE  21.0  MASCULINO      SOLTERO
# 96    ARMA BLANCA         A PIE         A PIE  34.0  MASCULINO       CASADO
# 97  ARMA DE FUEGO         A PIE         A PIE  23.0  MASCULINO      SOLTERO
# 98    ARMA BLANCA         A PIE         A PIE  70.0  MASCULINO     SEPARADO
# 99    ARMA BLANCA         A PIE         A PIE  20.0  MASCULINO      SOLTERO
#
#          CLASE EMPLEADO     PROFESION ESCOLARIDAD     PAIS NACE  CODIGO DANE  \
# 0         INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA    5030000.0
# 1           DESEMPLEADO  NO REPORTADO  SECUNDARIA  NO REPORTADO    5079000.0
# 2            AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5250000.0
# 3            AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5364000.0
# 4           DESEMPLEADO  NO REPORTADO    PRIMARIA      COLOMBIA    5001000.0
# ..                  ...           ...         ...           ...          ...
# 95          DESEMPLEADO  NO REPORTADO  SECUNDARIA      COLOMBIA   73319000.0
# 96          DESEMPLEADO  NO REPORTADO    PRIMARIA      COLOMBIA   73001000.0
# 97  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA      COLOMBIA   73443000.0
# 98  EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA      COLOMBIA   73504000.0
# 99          DESEMPLEADO  NO REPORTADO  SECUNDARIA      COLOMBIA   73671000.0
#
#     AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 0              1971.0  42-908  agbnqg2122@unidatos.edu.co
# 1              1985.0  15-183        rbkeui3584@gmail.com
# 2              1982.0  84-786  aorkhf9155@unidatos.edu.co
# 3              1975.0  31-289  dhtemr6623@unidatos.edu.co
# 4              1949.0  66-363  artatj9268@unidatos.edu.co
# ..                ...     ...                         ...
# 95             1994.0  73-094   correo863@unidatos.edu.co
# 96             1981.0  17-670        cgtpjq5472@gmail.com
# 97             1992.0  26-683  lfkdpc3495@unidatos.edu.co
# 98             1945.0  95-410  umcrgu3348@unidatos.edu.co
# 99             1995.0  61-699        lgslle6590@gmail.com
#
# [100 rows x 21 columns]

# %%
days_aut[days_aut['DIA'] == 'Miércoles']
# Out:
#                     FECHA DEPARTAMENTO            MUNICIPIO        DIA  \
# 274   2021-01-07 18:15:00    ANTIOQUIA              BARBOSA  Miércoles
# 275   2021-01-07 17:30:00    ANTIOQUIA             CISNEROS  Miércoles
# 276   2021-01-07 00:00:00       ARAUCA             SARAVENA  Miércoles
# 277   2021-01-07 21:00:00    ATLÁNTICO    BARRANQUILLA (CT)  Miércoles
# 278   2021-01-07 18:00:00    ATLÁNTICO          SABANALARGA  Miércoles
# ...                   ...          ...                  ...        ...
# 12343 2021-12-30 22:20:00        VALLE           CANDELARIA  Miércoles
# 12344 2021-12-30 09:38:00        VALLE           EL CERRITO  Miércoles
# 12345 2021-12-30 19:35:00        VALLE  GUADALAJARA DE BUGA  Miércoles
# 12346 2021-12-30 06:45:00        VALLE                TULUÁ  Miércoles
# 12347 2021-12-30 20:50:00        VALLE                TULUÁ  Miércoles
#
#                                BARRIO    ZONA         CLASE DE SITIO  \
# 274                   BARRIO DE JESUS  URBANA          VIAS PUBLICAS
# 275                          CAMELIAS   RURAL     FINCAS Y SIMILARES
# 276              VEREDA PUERTO NARIÑO   RURAL          VIAS PUBLICAS
# 277                          CARRIZAL  URBANA          VIAS PUBLICAS
# 278                   PRIMERO DE MAYO  URBANA  DENTRO DE LA VIVIENDA
# ...                               ...     ...                    ...
# 12343  PANAMERICANO (23NO REPORTADO2)  URBANA          VIAS PUBLICAS
# 12344                     LOS SAMANES  URBANA          VIAS PUBLICAS
# 12345                       LA MERCED  URBANA          VIAS PUBLICAS
# 12346       Urbanizacion Buenos Aires  URBANA          VIAS PUBLICAS
# 12347                          La Paz  URBANA          VIAS PUBLICAS
#
#         ARMA O MEDIO MOVIL VICTIMA         MOVIL AGRESOR  EDAD     GENERO  \
# 274    ARMA DE FUEGO         A PIE                 A PIE  29.0  MASCULINO
# 275    ARMA DE FUEGO         A PIE                 A PIE  20.0  MASCULINO
# 276     CONTUNDENTES         A PIE                 A PIE  70.0  MASCULINO
# 277    ARMA DE FUEGO         A PIE  PASAJERO MOTOCICLETA  43.0  MASCULINO
# 278     CONTUNDENTES         A PIE                 A PIE   1.0  MASCULINO
# ...              ...           ...                   ...   ...        ...
# 12343  ARMA DE FUEGO         A PIE                 A PIE  24.0  MASCULINO
# 12344  ARMA DE FUEGO         A PIE             BICICLETA  28.0  MASCULINO
# 12345  ARMA DE FUEGO      VEHICULO  PASAJERO MOTOCICLETA  31.0  MASCULINO
# 12346  ARMA DE FUEGO         A PIE                 A PIE  24.0  MASCULINO
# 12347  ARMA DE FUEGO         A PIE             BICICLETA  16.0   FEMENINO
#
#       ESTADO CIVIL       CLASE EMPLEADO     PROFESION ESCOLARIDAD PAIS NACE  \
# 274        SOLTERO          DESEMPLEADO  NO REPORTADO  SECUNDARIA  COLOMBIA
# 275        SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA
# 276        SOLTERO          COMERCIANTE  NO REPORTADO    PRIMARIA  COLOMBIA
# 277         CASADO        INDEPENDIENTE  NO REPORTADO     TECNICO  COLOMBIA
# 278        SOLTERO          DESEMPLEADO  NO REPORTADO  ANALFABETA  COLOMBIA
# ...            ...                  ...           ...         ...       ...
# 12343  UNION LIBRE        INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA
# 12344      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA
# 12345  UNION LIBRE  EMPLEADO PARTICULAR  NO REPORTADO    SUPERIOR  COLOMBIA
# 12346      SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA
# 12347      SOLTERO           ESTUDIANTE  NO REPORTADO  SECUNDARIA  COLOMBIA
#
#        CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 274      5079000.0               86.0  62-083        ocolgu9647@gmail.com
# 275      5190000.0             1995.0  34-931        oqlifs1273@gmail.com
# 276     81736000.0             1945.0  55-128  uaupkg5351@unidatos.edu.co
# 277      8001000.0             1972.0  72-066   correo540@unidatos.edu.co
# 278      8638000.0             2014.0  35-163  qjlump7011@unidatos.edu.co
# ...            ...                ...     ...                         ...
# 12343   76130000.0             1991.0  62-546  mtfdmb1912@unidatos.edu.co
# 12344   76248000.0             1987.0  52-938  tnlpkc3117@unidatos.edu.co
# 12345   76111000.0             1984.0  22-336  kqjbkh3438@unidatos.edu.co
# 12346   76834000.0             1991.0  50-889   correo650@unidatos.edu.co
# 12347   76834000.0             1999.0  79-280        bultar5811@gmail.com
#
# [1378 rows x 21 columns]

# %%
days_aut["DIA"].value_counts()
# Out:
# Domingo      2765
# Sábado       1848
# Lunes        1679
# Jueves       1637
# Viernes      1635
# Martes       1453
# Miércoles    1378
# Name: DIA, dtype: int64

# %% [markdown]
# ## 6. Recalculation based on a different column

# %%
homicides_df[["AÑO DE NACIMIENTO", "EDAD"]].sample(10)
# Out:
#       AÑO DE NACIMIENTO  EDAD
# 4509             1955.0  60.0
# 1292             1989.0  26.0
# 6798             1999.0  16.0
# 7770             1986.0  29.0
# 5331             1970.0  45.0
# 205              1998.0  17.0
# 7041             1993.0  22.0
# 9085             1967.0  48.0
# 7866             1989.0  26.0
# 9556             1969.0  46.0

# %% [markdown]
# <span style="color:red">TODO: Fix the "AÑO DE NACIMIENTO" column using the column "EDAD".</span>

# %%
import datetime
Edad_C = homicides_df
Edad_C['AÑO DE NACIMIENTO_CORREGIDO'] = datetime.datetime.now().year - Edad_C['EDAD']
Edad_C[['AÑO DE NACIMIENTO_CORREGIDO', "AÑO DE NACIMIENTO", "EDAD"]].sample(10)
# Out:
#        AÑO DE NACIMIENTO_CORREGIDO  AÑO DE NACIMIENTO  EDAD
# 10651                       1971.0             1963.0  52.0
# 7360                        2004.0             1996.0  19.0
# 11888                       1993.0             1985.0  30.0
# 8392                        2002.0             1994.0  21.0
# 2638                        2007.0             1999.0  16.0
# 2805                        1973.0             1965.0  50.0
# 5789                        1995.0             1987.0  28.0
# 10060                       1994.0             1986.0  29.0
# 1522                        1995.0             1987.0  28.0
# 3765                        1988.0             1980.0  35.0

# %%
Edad_C['AÑO DE NACIMIENTO'] = Edad_C['AÑO DE NACIMIENTO_CORREGIDO']
Edad_C[['AÑO DE NACIMIENTO_CORREGIDO', "AÑO DE NACIMIENTO", "EDAD"]].sample(10)
# Out:
#        AÑO DE NACIMIENTO_CORREGIDO  AÑO DE NACIMIENTO  EDAD
# 10097                       1998.0             1998.0  25.0
# 8916                        1990.0             1990.0  33.0
# 10266                       1983.0             1983.0  40.0
# 4078                        1971.0             1971.0  52.0
# 11507                       1999.0             1999.0  24.0
# 4378                        1999.0             1999.0  24.0
# 241                         1989.0             1989.0  34.0
# 9535                        1998.0             1998.0  25.0
# 8872                        2001.0             2001.0  22.0
# 11332                       1978.0             1978.0  45.0

# %% [markdown]
# ## 7. Conclusion
#
# <span style="color:red">Make a summary of the different data quality problems found on the dataset, the data quality dimension that is related to and the implemented strategy for solving or mitigating that specific problem.</span>

# %% [markdown]
# Consistencia (Cédula)
# Problema: Malformación de algunos datos en el atributo "Cédula".
# Estrategia: Utilizar funciones replace() para ajustar y estandarizar los valores de la "Cédula" y lograr consistencia.
#
# Conformidad (Departamentos)
# Problema: Varianza en los nombres de los departamentos.
# Estrategia: Utilizar funciones replace() para ajustar los valores de departamentos que no están dentro del diccionario y lograr conformidad.
#
# Duplicidad (Cédula)
# Problema: Duplicidad de registros en la columna "Cédula".
# Estrategia: Utilizar la función drop_duplicates() para eliminar registros duplicados y garantizar la conformidad de los datos.
#
# Conformidad (Días de la semana)
# Problema: Errores de digitación en los días de la semana.
# Estrategia: Utilizar una función con un bucle for y la librería pylev.levenshtein para corregir los datos y lograr conformidad.
#
# Precisión (Año de Nacimiento)
# Problema: Errores en el año de nacimiento.
# Estrategia: Calcular el año de nacimiento correcto restando la "Edad" al año actual para mejorar la precisión de los datos.
